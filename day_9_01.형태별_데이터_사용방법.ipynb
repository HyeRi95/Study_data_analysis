# %%
# bicycle.csv 파일을 읽어들인 후 조회
# 데이터 프레임 변수 df1
import pandas as pd

# %%
file_path = './data/bicycle.csv'
df1 = pd.read_csv(file_path,encoding ='euc-kr')
df1
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# ...

# %%
# bicycle.xlsx 파일 읽어들인 후 조회
# 변수명 df2 

file_path2 = './data/bicycle.xlsx'
df2 = pd.read_excel(file_path2)
df2
# Out:
#          자전거번호                대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220 2019-11-01 08:48:31    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216 2019-11-04 08:38:39    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097 2019-11-04 08:46:37    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292 2019-11-05 08:34:59    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935 2019-11-05 12:29:00    512        뚝섬역 1번 출구 옆   11.0
# ..         ...                 ...    ...                ...    ...
# 415  SPB-12116 2019-11-15 04:22:13    112            극동방송국 앞    5.0
# 416  SPB-17768 2019-11-15 09:31:48    103         망원역 2번출구 앞   14.0
# 417  SPB-18841 2019-11-15 20:40:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467 2019-11-15 21:55:13    152         마포구민체육센터 앞   18.0
# 419  SPB-17570 2019-11-15 22:16:08    391              정동길입구    7.0
#
#                    반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0   2019-11-01 09:01:24        3         중랑센터    7.0  12.0  1100.0
# ...

# %%
# read.json 파일 읽어들인 후 조회
# 변수명 df3
file_path3 = './data/read.json'
df3 = pd.read_json(file_path3)
df3
# key 값이 컬럼명
# Out:
#   1.FirstName 2.LastName  3.Age       4.University  \
# 0     Gildong       Hong     20  Gachon University
# 1     Gildong       Hong     20  Gachon University
#
#                                            5.Courses
# 0  {'Classes': ['Probability', 'Generalized Linea...
# 1  {'Classes': ['Data Structure', 'Programming', ...

# %%
# df1 저장하기
# 저장위치 : data2 폴더
# 저장파일명 : sample_data.csv 

df1.to_csv('./data2/sample_data.csv')

# %%
# df2 저장하기
# 저장위치 : data2 폴더
# 저장파일명 : sample_data.xlsx
df2.to_excel('./data2/sample_data.xlsx')

# %%
# df3 저장히기
# 저장위치 : data2 폴더
# 저장파일명 : sample_data.json
df3.to_json('./data2/sample_data.json')

# %% [markdown]
# # 데이터 수집 : Open API 방식

# %%
# 서비스키에 일반 인증키(Encoding) 넣는다 
import requests

url = 'http://apis.data.go.kr/B551182/pharmacyInfoService/getParmacyBasisList'
params ={'serviceKey' : '60GaAMkAousnFvjCMk8NNWdIXnkeYsfNEfrn6PfNFawz19tosICB4CnFddyQKJANrWXFA7Ezx%2FrX3NOplwCgWA%3D%3D', 'pageNo' : '1', 'numOfRows' : '10', 'sidoCd' : '110000', 'sgguCd' : '110019', 'emdongNm' : '신내동', 'yadmNm' : '온누리건강', 'xPos' : '127.0965441345503', 'yPos' : '37.60765568913871', 'radius' : '3000' }

url = 'http://apis.data.go.kr/B551182/pharmacyInfoService/getParmacyBasisList?pageNo=1&numOfRows=10&sidoCd=110000&sgguCd=110019&emdongNm=신내동&yadmNm=온누리&xPos=127.0965441345503&yPos=37.60765568913871&radius=3000&ServiceKey=60GaAMkAousnFvjCMk8NNWdIXnkeYsfNEfrn6PfNFawz19tosICB4CnFddyQKJANrWXFA7Ezx%2FrX3NOplwCgWA%3D%3D'
# response = requests.get(url, params=params)
response = requests.get(url)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><addr>\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xec\xa4\x91\xeb\x9e\x91\xea\xb5\xac \xeb\xb4\x89\xed\x99\x94\xec\x82\xb0\xeb\xa1\x9c 215 1\xec\xb8\xb5 (\xec\x8b\xa0\xeb\x82\xb4\xeb\x8f\x99)</addr><clCd>81</clCd><clCdNm>\xec\x95\xbd\xea\xb5\xad</clCdNm><distance>.5478450769582605437588497466708942455</distance><emdongNm>\xec\x8b\xa0\xeb\x82\xb4\xeb\x8f\x99</emdongNm><estbDd>20001222</estbDd><postNo>02054</postNo><sgguCd>110019</sgguCd><sgguCdNm>\xec\xa4\x91\xeb\x9e\x91\xea\xb5\xac</sgguCdNm><sidoCd>110000</sidoCd><sidoCdNm>\xec\x84\x9c\xec\x9a\xb8</sidoCdNm><telno>02-3422-3097</telno><XPos>127.0965492</XPos><YPos>37.6076585</YPos><yadmNm>\xec\x98\xa8\xeb\x88\x84\xeb\xa6\xac\xea\xb1\xb4\xea\xb0\x95\xec\x95\xbd\xea\xb5\xad</yadmNm><ykiho>JDQ4MTg4MSM1MSMkMSMkNCMkMDMkMzgxOTYxIzExIyQxIyQ3IyQ4MiQyNjEyMjIjO
# ...

# %%
# ? 기준 왼쪽 키 오른쪽 value
import requests

apikey = '60GaAMkAousnFvjCMk8NNWdIXnkeYsfNEfrn6PfNFawz19tosICB4CnFddyQKJANrWXFA7Ezx%2FrX3NOplwCgWA%3D%3D'

pageNo = 1
numOfRows= 10 # 10개씩 보여준다 
sidoCd = 110000
sgguCd = 110019
emdongNm='신내동'
yadmNm='온누리'
xPos=127.0965441345503
yPos=37.60765568913871
radius=3000

api = '''http://apis.data.go.kr/B551182/pharmacyInfoService/getParmacyBasisList?
         pageNo={no}&numOfRows={row}&sidoCd={sido}&sgguCd={sigu}&emdongNm={dong}&
         yadmNm={yanm}&xPos={x}&yPos={y}&radius={r}&ServiceKey={key}'''


# format 사용방식 3가지
# f.'{pageNo}{sidoCd}'
# {}{}.format(pageNo, sidoCd)

url = api.format(no = pageNo, 
                 row = numOfRows,
                 sido = sidoCd, 
                 sigu = sgguCd, 
                 dong = emdongNm, 
                 yanm = yadmNm,
                 x = xPos,
                 y = yPos,
                 r = radius,
                 key=apikey)

response = requests.get(url)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><addr>\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xec\xa4\x91\xeb\x9e\x91\xea\xb5\xac \xeb\xb4\x89\xed\x99\x94\xec\x82\xb0\xeb\xa1\x9c 217 (\xec\x8b\xa0\xeb\x82\xb4\xeb\x8f\x99, \xec\x98\xa4\xec\x83\x81\xeb\xb9\x8c\xeb\x94\xa9\xeb\x82\xb4)</addr><clCd>81</clCd><clCdNm>\xec\x95\xbd\xea\xb5\xad</clCdNm><distance>29.201392157360951119304450671869946358</distance><emdongNm>\xec\x8b\xa0\xeb\x82\xb4\xeb\x8f\x99</emdongNm><estbDd>20010705</estbDd><postNo>02054</postNo><sgguCd>110019</sgguCd><sgguCdNm>\xec\xa4\x91\xeb\x9e\x91\xea\xb5\xac</sgguCdNm><sidoCd>110000</sidoCd><sidoCdNm>\xec\x84\x9c\xec\x9a\xb8</sidoCdNm><telno>02-3422-2755</telno><XPos>127.0968401</XPos><YPos>37.6077698</YPos><yadmNm>\xec\x9c\xa0\xec\x8b\xac\xec\x95\xbd\xea\xb5\xad</yadmNm><ykiho>JDQ4MTg4MSM1MSMkMSMkNCMkMDMkMzgxOTYxIzIxIyQxIyQ1IyQ5
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
response
# Out:
# <Response [200]>

# %%
re = response.text
soup = BeautifulSoup(re, 'html.parser')
# soup 데이터에서 <addr> 태그 가진값 모두 찾기 <addr> ~~~~~ </addr> 
addr_list = soup.find_all('addr') # <- 리스트 형식 
addr_list
# 0번째 값 추출 
addr_list[0]
#0번째 태그안에 있는 text 값 추출하기  

addr_list[0].text
# Out:
# '서울특별시 중랑구 봉화산로 217 (신내동, 오상빌딩내)'

# %%
tel_list= soup.find_all('telno')
tel_list
# Out:
# [<telno>02-3422-2755</telno>,
#  <telno>3423-0808</telno>,
#  <telno>02-3422-6953</telno>,
#  <telno>02-2207-3356</telno>,
#  <telno>02-3422-3097</telno>,
#  <telno>070-8805-8844</telno>,
#  <telno>02-3421-8586</telno>,
#  <telno>070-4229-9602</telno>,
#  <telno>02-3421-7582</telno>,
#  <telno>3421-4200</telno>]

# %%
# for 문 사용전에 두개의 리스트의 갯수 확인한다 같으면 인덱스로 값 추출하는 for문에 두 리스트 넣어서 사용가능 
print('addr_list = ', len(addr_list))
print('tel_list = ', len(tel_list))
# 각 태그의 text값만 추출하기 (인덱스로)
for i in range(0,len(addr_list),1):
    print('약국주소 : ', addr_list[i].text)
    print('전화번호 : ', tel_list[i].text) # 인덱스로 추출하기 때문에 key 값에 따른 value값 여러개 추출가능
# Out:
# addr_list =  10
# tel_list =  10
# 약국주소 :  서울특별시 중랑구 봉화산로 217 (신내동, 오상빌딩내)
# 전화번호 :  02-3422-2755
# 약국주소 :  서울특별시 중랑구 신내로16길 17 1층 (신내동)
# 전화번호 :  3423-0808
# 약국주소 :  서울특별시 중랑구 신내로 201 1층 (신내동, 홈플러스 서울 신내점)
# 전화번호 :  02-3422-6953
# 약국주소 :  서울특별시 중랑구 신내로 45 해성빌딩 1층 (신내동)
# 전화번호 :  02-2207-3356
# 약국주소 :  서울특별시 중랑구 봉화산로 215 1층 (신내동)
# 전화번호 :  02-3422-3097
# 약국주소 :  서울특별시 중랑구 신내로 72 원빌딩 (신내동)
# 전화번호 :  070-8805-8844
# 약국주소 :  서울특별시 중랑구 신내로16길 17 1층 104호 (신내동)
# 전화번호 :  02-3421-8586
# 약국주소 :  서울특별시 중랑구 신내로 225 266호 (신내동, 디아뜨갤러리)
# 전화번호 :  070-4229-9602
# 약국주소 :  서울특별시 중랑구 신내로 135 신내9단지아파트 제상가1동 1층 117호 (신내동)
# 전화번호 :  02-3421-7582
# 약국주소 :  서울특별시 중랑구 신내로16길 17 105호 (신내동)
# 전화번호 :  3421-4200

# %%
# 각 태그의 text값만 추출하기 (값으로) 인덱스 번호가 아니기때문에 다른 값 가지고 오려면 for문 여러개 만들어야한다 
for i in addr_list:
    print('약국주소 : ',i.text)
# Out:
# 약국주소 :  서울특별시 중랑구 봉화산로 217 (신내동, 오상빌딩내)
# 약국주소 :  서울특별시 중랑구 신내로16길 17 1층 (신내동)
# 약국주소 :  서울특별시 중랑구 신내로 201 1층 (신내동, 홈플러스 서울 신내점)
# 약국주소 :  서울특별시 중랑구 신내로 45 해성빌딩 1층 (신내동)
# 약국주소 :  서울특별시 중랑구 봉화산로 215 1층 (신내동)
# 약국주소 :  서울특별시 중랑구 신내로 72 원빌딩 (신내동)
# 약국주소 :  서울특별시 중랑구 신내로16길 17 1층 104호 (신내동)
# 약국주소 :  서울특별시 중랑구 신내로 225 266호 (신내동, 디아뜨갤러리)
# 약국주소 :  서울특별시 중랑구 신내로 135 신내9단지아파트 제상가1동 1층 117호 (신내동)
# 약국주소 :  서울특별시 중랑구 신내로16길 17 105호 (신내동)

# %%
# 약국이름 ,시도명, 주소, 전화번호에 대한 text 값만 추출하여
# 각각의 리스트에 담기 변수명은 아래처럼
# yad_txt_list ,sido_txt_list, addr_txt_list, telno_txt_list

# %%
yad_list = soup.find_all('yadmnm')
sido_list = soup.find_all('sidocdnm')
addr_list = soup.find_all('addr')
telno_list = soup.find_all('telno')

telno_list
# 태그 대문자 소문자 확인 잘해서 넣자
# Out:
# [<telno>02-3422-2755</telno>,
#  <telno>3423-0808</telno>,
#  <telno>02-3422-6953</telno>,
#  <telno>02-2207-3356</telno>,
#  <telno>02-3422-3097</telno>,
#  <telno>070-8805-8844</telno>,
#  <telno>02-3421-8586</telno>,
#  <telno>070-4229-9602</telno>,
#  <telno>02-3421-7582</telno>,
#  <telno>3421-4200</telno>]

# %% [markdown]
# # 데이터 프레임 만들기 1

# %%
# 전역변수
yad_txt_list =[]
sido_txt_list=[]
addr_txt_list=[]
telno_txt_list=[]

for i in range(0,len(addr_list),1):
    yad_txt_list.append(yad_list[i].text)
    sido_txt_list.append(sido_list[i].text)
    addr_txt_list.append(addr_list[i].text)
    telno_txt_list.append(telno_list[i].text)
    
# print(yad_txt_list)
# print(sido_txt_list)
# print(addr_txt_list)
# print(telno_txt_list)

# 리스트를 데이터 프레임으로 변환 
df_temp=pd.DataFrame({'약국이름': yad_txt_list,
                      '시도명' : sido_txt_list,
                      '주소' : addr_txt_list,
                      '전화번호' : telno_txt_list})
df_temp
# Out:
#        약국이름 시도명                                              주소           전화번호
# 0      유심약국  서울                 서울특별시 중랑구 봉화산로 217 (신내동, 오상빌딩내)   02-3422-2755
# 1    서울동산약국  서울                    서울특별시 중랑구 신내로16길 17 1층 (신내동)      3423-0808
# 2    원플러스약국  서울         서울특별시 중랑구 신내로 201 1층 (신내동, 홈플러스 서울 신내점)   02-3422-6953
# 3      동남약국  서울                  서울특별시 중랑구 신내로 45 해성빌딩 1층 (신내동)   02-2207-3356
# 4   온누리건강약국  서울                     서울특별시 중랑구 봉화산로 215 1층 (신내동)   02-3422-3097
# 5      오성약국  서울                      서울특별시 중랑구 신내로 72 원빌딩 (신내동)  070-8805-8844
# 6  친절한 명성약국  서울               서울특별시 중랑구 신내로16길 17 1층 104호 (신내동)   02-3421-8586
# 7     한사랑약국  서울            서울특별시 중랑구 신내로 225 266호 (신내동, 디아뜨갤러리)  070-4229-9602
# 8      건강약국  서울  서울특별시 중랑구 신내로 135 신내9단지아파트 제상가1동 1층 117호 (신내동)   02-3421-7582
# 9      대한약국  서울                  서울특별시 중랑구 신내로16길 17 105호 (신내동)      3421-4200

# %% [markdown]
# # 데이터 프레임 만들기 2

# %%
new_all = []
for i in range(0,len(addr_txt_list),1):
    new =[ yad_txt_list[i],sido_txt_list[i],addr_txt_list[i],telno_txt_list[i]]
#     print(new)
    new_all.append(new) 
print(new_all)

# new[i] < 하면 new 리스트 안에 인덱스 0번째 값을 가진 값이 들어간다 
# ex) new = ['유심약국', '서울', '서울특별시 중랑구 봉화산로 217 (신내동, 오상빌딩내)', '02-3422-2755']
# new[0] = '유심약국' , new[1]='서울' ,,,,, 
# 이기때문에 인덱스가 4개 뿐이라 index 범위 에러가 발생한다 
# new_all 리스트안에 new 리스트 전체값을 넣기위해서는  new_all.append(new) 사용해야한다 

col_nm=['약국이름','시도명','주소','전화번호']
new_df = pd.DataFrame(new_all, columns = col_nm)
new_df
# Out:
# [['유심약국', '서울', '서울특별시 중랑구 봉화산로 217 (신내동, 오상빌딩내)', '02-3422-2755'], ['서울동산약국', '서울', '서울특별시 중랑구 신내로16길 17 1층 (신내동)', '3423-0808'], ['원플러스약국', '서울', '서울특별시 중랑구 신내로 201 1층 (신내동, 홈플러스 서울 신내점)', '02-3422-6953'], ['동남약국', '서울', '서울특별시 중랑구 신내로 45 해성빌딩 1층 (신내동)', '02-2207-3356'], ['온누리건강약국', '서울', '서울특별시 중랑구 봉화산로 215 1층 (신내동)', '02-3422-3097'], ['오성약국', '서울', '서울특별시 중랑구 신내로 72 원빌딩 (신내동)', '070-8805-8844'], ['친절한 명성약국', '서울', '서울특별시 중랑구 신내로16길 17 1층 104호 (신내동)', '02-3421-8586'], ['한사랑약국', '서울', '서울특별시 중랑구 신내로 225 266호 (신내동, 디아뜨갤러리)', '070-4229-9602'], ['건강약국', '서울', '서울특별시 중랑구 신내로 135 신내9단지아파트 제상가1동 1층 117호 (신내동)', '02-3421-7582'], ['대한약국', '서울', '서울특별시 중랑구 신내로16길 17 105호 (신내동)', '3421-4200']]
#        약국이름 시도명                                              주소           전화번호
# 0      유심약국  서울                 서울특별시 중랑구 봉화산로 217 (신내동, 오상빌딩내)   02-3422-2755
# 1    서울동산약국  서울                    서울특별시 중랑구 신내로16길 17 1층 (신내동)      3423-0808
# ...

# %% [markdown]
# # OpenAPI 연습

# %% [markdown]
# - https://www.airport.co.kr/www/index.do
#
#         한국 공항공사

# %% [markdown]
# 공항명(영문), 공항명(국문),주차장명 , 주차장 혼잡도 , 혼잡률, 입고된 차량수, 전체 주차면수

# %% [markdown]
# ### 김해공항 데이터

# %%
import requests

#################################1단계 데이터 수집 
serviceKey = 'PVdeh44WlF%2BHj6bGzfI2BXUldlea7Ggo%2FjjXvhbHCMNNFotchb2byGTopt4uAFS07RQzqmeU3M2Y8HcMmlYW9w%3D%3D'
pageNo = 1
numOfRows= 10
schAirportCode='PUS'

# 활용가이드.docx 파일에  <<<요청 / 응답 메시지 예제>>> 있는 코드 가져다 사용 
api = 'http://openapi.airport.co.kr/service/rest/AirportParkingCongestion/airportParkingCongestionRT?schAirportCode={aircode}&serviceKey={key}&numOfRows={row}&pageNo={no}'


# format 사용방식 3가지
# f.'{pageNo}{sidoCd}'
# {}{}.format(pageNo, sidoCd)

url = api.format(aircode = schAirportCode, 
                 key=serviceKey,
                 row = numOfRows,
                 no = pageNo)

response = requests.get(url)
print(response2.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><airportEng>GIMHAE INTERNATIONAL AIRPORT</airportEng><airportKor>\xea\xb9\x80\xed\x95\xb4\xea\xb5\xad\xec\xa0\x9c\xea\xb3\xb5\xed\x95\xad</airportKor><parkingAirportCodeName>P1\xec\x97\xac\xea\xb0\x9d\xec\xa3\xbc\xec\xb0\xa8\xec\x9e\xa5</parkingAirportCodeName><parkingCongestion>\xec\x9b\x90\xed\x99\x9c</parkingCongestion><parkingCongestionDegree>63.92%</parkingCongestionDegree><parkingOccupiedSpace>1497</parkingOccupiedSpace><parkingTotalSpace>2342</parkingTotalSpace><sysGetdate>2022-06-20</sysGetdate><sysGettime>15:13:03</sysGettime></item><item><airportEng>GIMHAE INTERNATIONAL AIRPORT</airportEng><airportKor>\xea\xb9\x80\xed\x95\xb4\xea\xb5\xad\xec\xa0\x9c\xea\xb3\xb5\xed\x95\xad</airportKor><parkingAirportCodeName>P2\xec\x97\xac\xea\xb0\x9d\xec\xa3\xbc\xec\xb0\xa8\xec\x9e\xa5</parkingAirportCodeName><parkingCongest
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
response
# Out:
# <Response [200]>

# %%
########################2단계 html 형태로 의미부여하기 
re = response.text
soup = BeautifulSoup(re, 'html.parser')
airportkor_list = soup.find_all('airportkor') # <- 리스트 형식 ########### soup 거치면서 대문자 -> 소문자 ###########
airporteng_list = soup.find_all('airporteng')
parkingairport_list = soup.find_all('parkingairportcodename')
congestion_list = soup.find_all('parkingcongestion')
degree_list = soup.find_all('parkingcongestiondegree')
occupation_list = soup.find_all('parkingoccupiedspace')
totalspace_list = soup.find_all('parkingtotalspace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 ########################2단계 html 형태로 의미부여하기
# ----> 2 re = response.text
#       3 soup = BeautifulSoup(re, 'html.parser')
#       4 airportkor_list = soup.find_all('airportkor') # <- 리스트 형식 ########### soup 거치면서 대문자 -> 소문자 ###########
#
# NameError: name 'response' is not defined

# %%
airportkor_txt_list =[]
airporteng_txt_list=[]
parkingairport_txt_list=[]
congestion_txt_list=[]
degree_txt_list=[]
occupation_txt_list=[]
totalspace_txt_list=[]

for i in range(0,len(airportkor_list),1):
    airportkor_txt_list.append(airportkor_list[i].text)
    airporteng_txt_list.append(airporteng_list[i].text)
    parkingairport_txt_list.append(parkingairport_list[i].text)
    congestion_txt_list.append(congestion_list[i].text)
    degree_txt_list.append(degree_list[i].text)
    occupation_txt_list.append(occupation_list[i].text)
    totalspace_txt_list.append(totalspace_list[i].text)
    
# 리스트를 데이터 프레임으로 변환 
df_temp=pd.DataFrame({'공항명(국문)': airportkor_txt_list,
                      '공항명(영문)' : airporteng_txt_list,
                      '주차장명' : parkingairport_txt_list,
                      '주차장혼잡도' : congestion_txt_list,
                      '주차장혼잡률' : degree_txt_list,
                      '입고된 차량수' : occupation_txt_list,
                      '전체주차면수' : totalspace_txt_list,})
df_temp
# Out:
#   공항명(국문)                       공항명(영문)         주차장명 주차장혼잡도  주차장혼잡률 입고된 차량수  \
# 0  김해국제공항  GIMHAE INTERNATIONAL AIRPORT      P1여객주차장     원활  63.92%    1497
# 1  김해국제공항  GIMHAE INTERNATIONAL AIRPORT      P2여객주차장     원활  61.63%    1105
# 2  김해국제공항  GIMHAE INTERNATIONAL AIRPORT  P3여객(화물)주차장     원활   43.9%     432
# 3  김해국제공항  GIMHAE INTERNATIONAL AIRPORT  P4여객(화물)주차장     원활  72.07%     480
#
#   전체주차면수
# 0   2342
# 1   1793
# 2    984
# 3    666

# %% [markdown]
# ### 김포공항 데이터

# %%
serviceKey = 'PVdeh44WlF%2BHj6bGzfI2BXUldlea7Ggo%2FjjXvhbHCMNNFotchb2byGTopt4uAFS07RQzqmeU3M2Y8HcMmlYW9w%3D%3D'
pageNo = 1
numOfRows= 10
schAirportCode='GMP'

api = 'http://openapi.airport.co.kr/service/rest/AirportParkingCongestion/airportParkingCongestionRT?schAirportCode={aircode}&serviceKey={key}&numOfRows={row}&pageNo={no}'

url = api.format(aircode = schAirportCode, 
                 key=serviceKey,
                 row = numOfRows,
                 no = pageNo)

response = requests.get(url)

# %%
from bs4 import BeautifulSoup
import requests

# %%
re = response.text
soup = BeautifulSoup(re, 'html.parser')
# soup 데이터에서 <addr> 태그 가진값 모두 찾기 <addr> ~~~~~ </addr> 
airportkor_list = soup.find_all('airportkor') # <- 리스트 형식 ###### 대소문자 ######
airporteng_list = soup.find_all('airporteng')
parkingairport_list = soup.find_all('parkingairportcodename')
congestion_list = soup.find_all('parkingcongestion')
degree_list = soup.find_all('parkingcongestiondegree')
occupation_list = soup.find_all('parkingoccupiedspace')
totalspace_list = soup.find_all('parkingtotalspace')

# %%
airportkor_txt_list =[]
airporteng_txt_list=[]
parkingairport_txt_list=[]
congestion_txt_list=[]
degree_txt_list=[]
occupation_txt_list=[]
totalspace_txt_list=[]

for i in range(0,len(airportkor_list),1):
    airportkor_txt_list.append(airportkor_list[i].text)
    airporteng_txt_list.append(airporteng_list[i].text)
    parkingairport_txt_list.append(parkingairport_list[i].text)
    congestion_txt_list.append(congestion_list[i].text)
    degree_txt_list.append(degree_list[i].text)
    occupation_txt_list.append(occupation_list[i].text)
    totalspace_txt_list.append(totalspace_list[i].text)
    
# 리스트를 데이터 프레임으로 변환 
df_temp_GMP=pd.DataFrame({'공항명(국문)': airportkor_txt_list,
                      '공항명(영문)' : airporteng_txt_list,
                      '주차장명' : parkingairport_txt_list,
                      '주차장혼잡도' : congestion_txt_list,
                      '주차장혼잡률' : degree_txt_list,
                      '입고된 차량수' : occupation_txt_list,
                      '전체주차면수' : totalspace_txt_list,})
df_temp_GMP
# Out:
#   공항명(국문)                      공항명(영문)       주차장명 주차장혼잡도  주차장혼잡률 입고된 차량수  \
# 0  김포국제공항  GIMPO INTERNATIONAL AIRPORT  [상세]예약주차장     원활  15.36%      51
# 1  김포국제공항  GIMPO INTERNATIONAL AIRPORT  국내선 제1주차장     혼잡  90.39%    2060
# 2  김포국제공항  GIMPO INTERNATIONAL AIRPORT  국내선 제2주차장     원활   88.2%    1540
# 3  김포국제공항  GIMPO INTERNATIONAL AIRPORT   국제선 주차빌딩     원활      0%       0
# 4  김포국제공항  GIMPO INTERNATIONAL AIRPORT  국제선 지하주차장     원활  19.17%     230
# 5  김포국제공항  GIMPO INTERNATIONAL AIRPORT   화물청사 주차장     원활   53.3%     606
#
#   전체주차면수
# 0    332
# 1   2279
# 2   1746
# 3    567
# 4   1200
# 5   1137

# %% [markdown]
# ### 공항 전체 데이터

# %%
airport_nm =['GMP','PUS','CJU','TAE','KWJ','RSU','USN','KUV','WJU','CJJ'] # 문자열 '' 

result = pd.DataFrame()
for i in airport_nm :
    serviceKey = 'PVdeh44WlF%2BHj6bGzfI2BXUldlea7Ggo%2FjjXvhbHCMNNFotchb2byGTopt4uAFS07RQzqmeU3M2Y8HcMmlYW9w%3D%3D'
    pageNo = 1
    numOfRows= 10
    schAirportCode=i

    api = 'http://openapi.airport.co.kr/service/rest/AirportParkingCongestion/airportParkingCongestionRT?schAirportCode={aircode}&serviceKey={key}&numOfRows={row}&pageNo={no}'

    url = api.format(aircode = schAirportCode, 
                     key=serviceKey,
                     row = numOfRows,
                     no = pageNo)
    response = requests.get(url)
    
    from bs4 import BeautifulSoup
    import requests
    
    re = response.text
    soup = BeautifulSoup(re, 'html.parser')
    # soup 데이터에서 <addr> 태그 가진값 모두 찾기 <addr> ~~~~~ </addr> 
    airportkor_list = soup.find_all('airportkor') # <- 리스트 형식 ###### 대소문자 ######
    airporteng_list = soup.find_all('airporteng')
    parkingairport_list = soup.find_all('parkingairportcodename')
    congestion_list = soup.find_all('parkingcongestion')
    degree_list = soup.find_all('parkingcongestiondegree')
    occupation_list = soup.find_all('parkingoccupiedspace')
    totalspace_list = soup.find_all('parkingtotalspace')
    airportkor_txt_list =[]
    airporteng_txt_list=[]
    parkingairport_txt_list=[]
    congestion_txt_list=[]
    degree_txt_list=[]
    occupation_txt_list=[]
    totalspace_txt_list=[]

    for i in range(0,len(airportkor_list),1):
        airportkor_txt_list.append(airportkor_list[i].text)
        airporteng_txt_list.append(airporteng_list[i].text)
        parkingairport_txt_list.append(parkingairport_list[i].text)
        congestion_txt_list.append(congestion_list[i].text)
        degree_txt_list.append(degree_list[i].text)
        occupation_txt_list.append(occupation_list[i].text)
        totalspace_txt_list.append(totalspace_list[i].text)

    # 리스트를 데이터 프레임으로 변환 
    df_temp_total=pd.DataFrame({'공항명(국문)': airportkor_txt_list,
                          '공항명(영문)' : airporteng_txt_list,
                          '주차장명' : parkingairport_txt_list,
                          '주차장혼잡도' : congestion_txt_list,
                          '주차장혼잡률' : degree_txt_list,
                          '입고된 차량수' : occupation_txt_list,
                          '전체주차면수' : totalspace_txt_list,})
    
    result = pd.concat([result,df_temp_total])
result
# Out:
# C:\Users\82102\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# ...

# %%
result
# Out:
#   공항명(국문)                         공항명(영문)         주차장명 주차장혼잡도  주차장혼잡률 입고된 차량수  \
# 0  김포국제공항     GIMPO INTERNATIONAL AIRPORT    [상세]예약주차장     원활  15.66%      52
# 1  김포국제공항     GIMPO INTERNATIONAL AIRPORT    국내선 제1주차장     혼잡  90.43%    2061
# 2  김포국제공항     GIMPO INTERNATIONAL AIRPORT    국내선 제2주차장     원활  87.86%    1534
# 3  김포국제공항     GIMPO INTERNATIONAL AIRPORT     국제선 주차빌딩     원활      0%       0
# 4  김포국제공항     GIMPO INTERNATIONAL AIRPORT    국제선 지하주차장     원활  18.75%     225
# 5  김포국제공항     GIMPO INTERNATIONAL AIRPORT     화물청사 주차장     원활  54.97%     625
# 0  김해국제공항    GIMHAE INTERNATIONAL AIRPORT      P1여객주차장     원활  63.15%    1479
# 1  김해국제공항    GIMHAE INTERNATIONAL AIRPORT      P2여객주차장     원활  61.74%    1107
# 2  김해국제공항    GIMHAE INTERNATIONAL AIRPORT  P3여객(화물)주차장     원활     44%     433
# 3  김해국제공항    GIMHAE INTERNATIONAL AIRPORT  P4여객(화물)주차장     원활  69.67%     464
# 0  제주국제공항      JEJU INTERNATIONAL AIRPORT           여객     혼잡  92.79%    1725
# ...

# %% [markdown]
# > 강사님 풀이

# %% [markdown]
# 수정필요

# %%
import requests
########## 1단계 데이터 수집...
list_all = []
new_df_total = pd.DataFrame()
apikey = "PVdeh44WlF%2BHj6bGzfI2BXUldlea7Ggo%2FjjXvhbHCMNNFotchb2byGTopt4uAFS07RQzqmeU3M2Y8HcMmlYW9w%3D%3D"
pageNo = 1
numOfRows = 10
#schAirportCode = "GMP"
schAirportCode = ["GMP", "PUS", "CJU", "TAE",
                  "KWJ", "RSU", "USN", "KUV",
                  "WJU", "CJJ"]

api = """http://openapi.airport.co.kr/service/rest/AirportParkingCongestion/airportParkingCongestionRT?schAirportCode={aircode}&pageNo={no}&numOfRows={row}&ServiceKey={key}"""

for acode in schAirportCode :
    url = api.format(no = pageNo,
                     row = numOfRows,
                     aircode = acode,
                     key = apikey)

    response = requests.get(url)
    response.text
    
    from bs4 import BeautifulSoup
    import requests
    ######################### 2단계...html 형태로 의미 부여하기..

    re = response.text
    soup = BeautifulSoup(re, "html.parser")
    soup

    #########################

    airportkor = soup.find_all("airportkor")
    parkingairportcodename = soup.find_all("parkingairportcodename")
    parkingcongestion = soup.find_all("parkingcongestion")
    parkingcongestiondegree = soup.find_all("parkingcongestiondegree")
    parkingoccupiedspace = soup.find_all("parkingoccupiedspace")
    parkingtotalspace = soup.find_all("parkingtotalspace")
    sysgetdate = soup.find_all("sysgetdate")
    sysgettime = soup.find_all("sysgettime")


    # for i in range(0, len(airportkor), 1) :
    #     print("공항이름", airportkor[i])
    #     print("주차장명", parkingairportcodename[i])
    #     print("혼잡도", parkingcongestion[i])
    #     print("혼잡율", parkingcongestiondegree[i])
    #     print("현재 주차대수", parkingoccupiedspace[i])
    #     print("전체 주차공간", parkingtotalspace[i])
    #     print("수집일자", sysgetdate[i])
    #     print("수집시간", sysgettime[i])


    for i in range(0, len(airportkor), 1) :
        list_all.append([airportkor[i].text,
                         parkingairportcodename[i].text,
                         parkingcongestion[i].text,
                         parkingcongestiondegree[i].text,
                         parkingoccupiedspace[i].text,
                         parkingtotalspace[i].text,
                         sysgetdate[i].text,
                         sysgettime[i].text])
    #     print(list_all)
        ################################
        col_nm = ["공항이름", "주차장명", "혼잡도", "혼잡율",
                  "현재 주차대수", "전체 주차공간", "수집일자", "수집시간"]
        new_df = pd.DataFrame(list_all, columns=col_nm)
#         print(new_df)
#         new_df_total = pd.concat([new_df_total,new_df])

# new_df_total
new_df
# Out:
# C:\Users\82102\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# ...
